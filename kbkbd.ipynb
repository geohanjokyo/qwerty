# %%
import torch
import torchvision
from IPython.display import Image  # for displaying images
from utils.google_utils import gdrive_download  # for downloading models/datasets
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b115d0cd28b8> in <module>
# ----> 1 import torch
#       2 import torchvision
#       3 from IPython.display import Image  # for displaying images
#       4 from utils.google_utils import gdrive_download  # for downloading models/datasets
#       5 print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
#
# ModuleNotFoundError: No module named 'torch'

# %%
# Start tensorboard
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 24076), started 0:01:52 ago. (Use '!kill 24076' to kill it.)
#       <iframe id="tensorboard-frame-6790168fb032905d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6790168fb032905d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !python train.py --img 128 --batch 400 --epochs 350 --data ./data.yaml --cfg ./models/yolov5x.yaml --weights '' --name temp --nosave --cache
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# ...

# %%
# !python detect.py --weights last_temp.pt --img 1088 --conf 0.4  --save-txt --source ./temp.png
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=720, iou_thres=0.5, output='inference/output', save_txt=True, source='./temp.png', update=False, view_img=False, weights=['last_temp.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2060 SUPER', total_memory=8192MB)
#
# Fusing layers... Model Summary: 140 layers, 7.51082e+06 parameters, 6.61683e+06 gradients
# WARNING: --img-size 720 must be multiple of max stride 32, updating to 736
# image 1/1 C:\Users\kimsu\yolov5qwerty\temp.png: 736x352 Done. (0.024s)
# Results saved to C:\Users\kimsu\yolov5qwerty\inference/output
# Done. (1.327s)

# %%
# !python detect.py --weights last_kbkbd.pt --img 64 --conf 0.4 --source ./qwertyl.png
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=64, iou_thres=0.5, output='inference/output', save_txt=False, source='./qwertyl.png', update=False, view_img=False, weights=['last_kbkbd.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2060 SUPER', total_memory=8192MB)
#
# Fusing layers... Model Summary: 284 layers, 8.90635e+07 parameters, 8.45317e+07 gradients
# image 1/1 C:\Users\kimsu\yolov5\qwertyl.png: 64x64 Done. (0.028s)
# Results saved to C:\Users\kimsu\yolov5\inference/output
# Done. (1.336s)

# %%
# !python detect.py --weights last_kbkbd.pt --img 800 --conf 0.4 --source ./numpads.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=800, iou_thres=0.5, output='inference/output', save_txt=False, source='./numpads.jpg', update=False, view_img=False, weights=['last_kbkbd.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2060 SUPER', total_memory=8192MB)
#
# Fusing layers... Model Summary: 284 layers, 8.90635e+07 parameters, 8.45317e+07 gradients
# image 1/1 C:\Users\kimsu\yolov5\numpads.jpg: 480x800 Done. (0.040s)
# Results saved to C:\Users\kimsu\yolov5\inference/output
# Done. (1.464s)

# %%
# !python detect.py --weights last_kbkbd.pt --img 64 --conf 0.4 --source ./numpadl.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=64, iou_thres=0.5, output='inference/output', save_txt=False, source='./numpadl.jpg', update=False, view_img=False, weights=['last_kbkbd.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2060 SUPER', total_memory=8192MB)
#
# Fusing layers... Model Summary: 284 layers, 8.90635e+07 parameters, 8.45317e+07 gradients
# image 1/1 C:\Users\kimsu\yolov5\numpadl.jpg: 64x64 Done. (0.030s)
# Results saved to C:\Users\kimsu\yolov5\inference/output
# Done. (1.339s)

# %%
Image(filename='runs/exp2_kbkbd/train_batch0.jpg', width=900)
